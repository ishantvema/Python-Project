# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv(r'C:\Users\ishan\Desktop\Projects\Python\Football\fifa_data.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
fifa['nationality'][0:10].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Slovenia', 'Belgium',
#        'Germany', 'Netherlands', 'Croatia', 'Egypt'], dtype=object)

# %%
plt.figure(figsize=(10,6))
plt.bar(list(fifa['nationality'].value_counts()[0:10].keys()),list(fifa['nationality'].value_counts()[0:10]),color='r')
plt.xticks(rotation='45')
plt.show()

# %%
player_salary=fifa[['short_name','wage_eur']]

# %%
player_salary.head(10)
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000
# 5       K. De Bruyne    370000
# 6      M. ter Stegen    250000
# 7        V. van Dijk    200000
# 8          L. Modrić    340000
# 9           M. Salah    240000

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head(10)
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 22       A. Griezmann    370000
# 5        K. De Bruyne    370000
# 19          L. Suárez    355000
# 8           L. Modrić    340000
# 36           T. Kroos    330000
# 21    Sergio Busquets    300000
# 18       Sergio Ramos    300000

# %%
plt.figure(figsize=(10,6))
plt.bar(list(player_salary['short_name'])[0:10],list(player_salary['wage_eur'])[0:10],color='r')
plt.xticks(rotation='45')
plt.show()

# %%
germany=fifa[fifa['nationality']=='Germany']

# %%
germany.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %%
germany.sort_values(by=['height_cm'],ascending=False).head(10)
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 13635     208776  https://sofifa.com/player/208776/florian-strit...
# 4449      158657  https://sofifa.com/player/158657/thomas-kessle...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 11147     235018  https://sofifa.com/player/235018/moritz-nicola...
# 16184     240218  https://sofifa.com/player/240218/alexander-wei...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# ...

# %%
germany.sort_values(by=['wage_eur'],ascending=False).head(10)
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 215     179846  https://sofifa.com/player/179846/sami-khedira/...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 135     176635  https://sofifa.com/player/176635/mesut-ozil/20...
#
#         short_name              long_name  age         dob  height_cm  \
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# ...

# %%
germany_sal=germany[['short_name','wage_eur']]

# %%
germany_sal.head(10)
# Out:
#         short_name  wage_eur
# 6    M. ter Stegen    250000
# 31        M. Neuer    155000
# 36        T. Kroos    330000
# 37         M. Reus    170000
# 49      M. Hummels    130000
# 55         L. Sané    195000
# 61      J. Kimmich    125000
# 70       T. Müller    170000
# 77         N. Süle    115000
# 109     K. Havertz     70000

# %%
germany_sal.sort_values(by=['wage_eur'],ascending=False).head(10)
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000
# 37         M. Reus    170000
# 31        M. Neuer    155000
# 215     S. Khedira    135000
# 49      M. Hummels    130000
# 135        M. Özil    125000

# %%
germany.sort_values(by=['weight_kg'],ascending=False).head(10)
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# 13201     241388  https://sofifa.com/player/241388/dennis-smarsc...
# 165       213331  https://sofifa.com/player/213331/jonathan-tah/...
# 5107      216284  https://sofifa.com/player/216284/florian-balla...
# 2746      224251  https://sofifa.com/player/224251/robin-zentner...
# 7574      216377  https://sofifa.com/player/216377/stefan-kutsch...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# ...

# %%
## defending

# %%
player_defending=fifa[['short_name','defending','nationality','club']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head(10)
# Out:
#          short_name  defending  nationality               club
# 16     G. Chiellini       90.0        Italy           Juventus
# 7       V. van Dijk       90.0  Netherlands          Liverpool
# 11     K. Koulibaly       89.0      Senegal             Napoli
# 35         D. Godín       89.0      Uruguay              Inter
# 49       M. Hummels       89.0      Germany  Borussia Dortmund
# 29            Piqué       88.0        Spain       FC Barcelona
# 50  T. Alderweireld       88.0      Belgium  Tottenham Hotspur
# 40       A. Laporte       88.0       France    Manchester City
# 47    J. Vertonghen       87.0      Belgium  Tottenham Hotspur
# 67       L. Bonucci       87.0        Italy           Juventus

# %%
real_madrid=fifa[fifa['club']=='Real Madrid']

# %%
real_madrid[['short_name','club','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head(10)
# Out:
#        short_name         club  wage_eur
# 4       E. Hazard  Real Madrid    470000
# 8       L. Modrić  Real Madrid    340000
# 36       T. Kroos  Real Madrid    330000
# 18   Sergio Ramos  Real Madrid    300000
# 46     K. Benzema  Real Madrid    285000
# 100       G. Bale  Real Madrid    250000
# 62           Isco  Real Madrid    245000
# 42       Casemiro  Real Madrid    240000
# 28    T. Courtois  Real Madrid    235000
# 106  J. Rodríguez  Real Madrid    225000

# %%
real_madrid[['short_name','club','shooting']].sort_values(by=['shooting'],ascending=False).head(10)
# Out:
#         short_name         club  shooting
# 100        G. Bale  Real Madrid      87.0
# 106   J. Rodríguez  Real Madrid      86.0
# 4        E. Hazard  Real Madrid      83.0
# 46      K. Benzema  Real Madrid      82.0
# 161       L. Jović  Real Madrid      82.0
# 36        T. Kroos  Real Madrid      80.0
# 178  Marco Asensio  Real Madrid      80.0
# 636        Mariano  Real Madrid      80.0
# 62            Isco  Real Madrid      77.0
# 8        L. Modrić  Real Madrid      76.0

# %%
real_madrid[['short_name','club','defending']].sort_values(by=['defending'],ascending=False).head(10)
# Out:
#           short_name         club  defending
# 18      Sergio Ramos  Real Madrid       87.0
# 42          Casemiro  Real Madrid       85.0
# 76         R. Varane  Real Madrid       85.0
# 94          Carvajal  Real Madrid       82.0
# 332     Éder Militão  Real Madrid       81.0
# 277  Nacho Fernández  Real Madrid       81.0
# 101          Marcelo  Real Madrid       77.0
# 437        Odriozola  Real Madrid       77.0
# 424         F. Mendy  Real Madrid       75.0
# 8          L. Modrić  Real Madrid       72.0

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Germany                1
# Serbia                 1
# Colombia               1
# Costa Rica             1
# Wales                  1
# Uruguay                1
# Croatia                1
# Dominican Republic     1
# Japan                  1
# Name: nationality, dtype: int64
